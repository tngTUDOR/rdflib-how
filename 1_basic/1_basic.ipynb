# %% [markdown]
# # Very basic example
#
# This is to validate that we can reproduce the example from the official docs:
#
# https://rdflib.readthedocs.io/en/stable/gettingstarted.html

# %% [markdown]
# ## Loading data from an URL
#
# `RDFlib` includes the infrastructure to directly fetch data from an http URL.

# %%
import rdflib

# %%
g = rdflib.Graph()
result = g.parse("http://www.w3.org/People/Berners-Lee/card")

# %%
print("graph has %s statements." % len(g))
# Out:
# graph has 87 statements.

# %%
for subj, pred, obj in g:
   if (subj, pred, obj) not in g:
       raise Exception("It better be!")

# %%
s = g.serialize(format='n3') #shorthand non-XML serialization (https://en.wikipedia.org/wiki/Notation3)
print(s.decode())
# Out:
# @prefix : <http://xmlns.com/foaf/0.1/> .
# @prefix cc: <http://creativecommons.org/ns#> .
# @prefix cert: <http://www.w3.org/ns/auth/cert#> .
# @prefix con: <http://www.w3.org/2000/10/swap/pim/contact#> .
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix default1: <http://www.w3.org/ns/auth/acl#> .
# @prefix doap: <http://usefulinc.com/ns/doap#> .
# @prefix geo: <http://www.w3.org/2003/01/geo/wgs84_pos#> .
# @prefix ldp: <http://www.w3.org/ns/ldp#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix sioc: <http://rdfs.org/sioc/ns#> .
# @prefix solid: <http://www.w3.org/ns/solid/terms#> .
# @prefix space: <http://www.w3.org/ns/pim/space#> .
# @prefix vcard: <http://www.w3.org/2006/vcard/ns#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://dig.csail.mit.edu/2005/ajar/ajaw/data#Tabulator> doap:developer <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://dig.csail.mit.edu/2007/01/camp/data#course> :maker <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://dig.csail.mit.edu/data#DIG> :member <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://wiki.ontoworld.org/index.php/_IRW2006> dc:title "Identity, Reference and the Web workshop 2006" ;
#     con:participant <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://www.ecs.soton.ac.uk/~dt2/dlstuff/www2006_data#panel-panelk01> rdfs:label "The Next Wave of the Web (Plenary Panel)" ;
#     con:participant <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://www.w3.org/2000/10/swap/data#Cwm> doap:developer <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://www.w3.org/2011/Talks/0331-hyderabad-tbl/data#talk> dct:title "Designing the Web for an Open Society" ;
#     :maker <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://www.w3.org/DesignIssues/Overview.html> dc:title "Design Issues for the World Wide Web" ;
#     :maker <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://www.w3.org/People/Berners-Lee/card> a :PersonalProfileDocument ;
#     cc:license <http://creativecommons.org/licenses/by-nc/3.0/> ;
#     dc:title "Tim Berners-Lee's FOAF file" ;
#     :maker <https://www.w3.org/People/Berners-Lee/card#i> ;
#     :primaryTopic <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://www.w3.org/People/Berners-Lee/card#i> = <https://www.w3.org/People/Berners-Lee/card#i> ;
#     cert:key [ a cert:RSAPublicKey ;
#             cert:exponent 65537 ;
#             cert:modulus "..."^^xsd:hexBinary ] .
#
# <http://www.w3.org/data#W3C> :member <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://dig.csail.mit.edu/breadcrumbs/blog/4> dc:title "timbl's blog on DIG" ;
#     rdfs:seeAlso <http://dig.csail.mit.edu/breadcrumbs/blog/feed/4> ;
#     :maker <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <https://timbl.com/timbl/Public/friends.ttl> a :PersonalProfileDocument ;
#     cc:license <http://creativecommons.org/licenses/by-nc/3.0/> ;
#     dc:title "Tim Berners-Lee's editable FOAF file" ;
#     :maker <https://www.w3.org/People/Berners-Lee/card#i> ;
#     :primaryTopic <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <https://www.w3.org/People/Berners-Lee/card#i> a con:Male,
#         :Person ;
#     rdfs:label "Tim Berners-Lee" ;
#     sioc:avatar <http://www.w3.org/People/Berners-Lee/images/timbl-image-by-Coz-cropped.jpg> ;
#     rdfs:seeAlso <https://timbl.com/timbl/Public/friends.ttl> ;
#     con:assistant <https://www.w3.org/People/Berners-Lee/card#amy> ;
#     con:homePage <http://www.w3.org/People/Berners-Lee/> ;
#     con:office [ con:address [ con:city "Cambridge" ;
#                     con:country "USA" ;
#                     con:postalCode "02139" ;
#                     con:street "32 Vassar Street" ;
#                     con:street2 "MIT CSAIL Room 32-G524" ] ;
#             con:phone <tel:+1-617-253-5702> ;
#             geo:location [ geo:lat "42.361860" ;
#                     geo:long "-71.091840" ] ] ;
#     con:preferredURI "https://www.w3.org/People/Berners-Lee/card#i" ;
#     con:publicHomePage <http://www.w3.org/People/Berners-Lee/> ;
#     vcard:fn "Tim Berners-Lee" ;
#     vcard:hasAddress [ a vcard:Work ;
#             vcard:locality "Cambridge" ;
#             vcard:postal-code "02139" ;
#             vcard:region "MA" ;
#             vcard:street-address "MIT room 32-G-52432 Vassar Street" ] ;
#     vcard:hasTelephone [ a vcard:Work ;
#             vcard:value <tel:+1-617-253-5702> ] ;
#     default1:delegates <https://databox.me:3200/webid#me> ;
#     ldp:inbox <https://timbl.com/timbl/Public/Inbox> ;
#     space:preferencesFile <https://timbl.com/timbl/Data/preferences.n3> ;
#     space:storage <https://timbl.databox.me/> ;
#     solid:oidcIssuer <https://timbl.com> ;
#     solid:publicTypeIndex <https://timbl.com/timbl/Public/PublicTypeIndex.ttl> ;
#     :account <http://en.wikipedia.org/wiki/User:Timbl>,
#         <http://twitter.com/timberners_lee>,
#         <http://www.reddit.com/user/timbl/> ;
#     :based_near [ geo:lat "42.361860" ;
#             geo:long "-71.091840" ] ;
#     :family_name "Berners-Lee" ;
#     :givenname "Timothy" ;
#     :homepage <https://www.w3.org/People/Berners-Lee/> ;
#     :img <https://www.w3.org/Press/Stock/Berners-Lee/2001-europaeum-eighth.jpg> ;
#     :mbox <mailto:timbl@w3.org> ;
#     :mbox_sha1sum "965c47c5a70db7407210cef6e4e6f5374a525c5c" ;
#     :name "Timothy Berners-Lee" ;
#     :nick "TimBL",
#         "timbl" ;
#     :openid <https://www.w3.org/People/Berners-Lee/> ;
#     :phone <tel:+1-(617)-253-5702> ;
#     :title "Sir" ;
#     :weblog <http://dig.csail.mit.edu/breadcrumbs/blog/4> ;
#     :workplaceHomepage <https://www.w3.org/> .

# %%
print(g.serialize(format='pretty-xml', encoding='utf-8').decode('utf-8'))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <rdf:RDF
#   xmlns="http://xmlns.com/foaf/0.1/"
#   xmlns:vcard="http://www.w3.org/2006/vcard/ns#"
#   xmlns:con="http://www.w3.org/2000/10/swap/pim/contact#"
#   xmlns:space="http://www.w3.org/ns/pim/space#"
#   xmlns:geo="http://www.w3.org/2003/01/geo/wgs84_pos#"
#   xmlns:solid="http://www.w3.org/ns/solid/terms#"
#   xmlns:sioc="http://rdfs.org/sioc/ns#"
#   xmlns:owl="http://www.w3.org/2002/07/owl#"
#   xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#   xmlns:dct="http://purl.org/dc/terms/"
#   xmlns:doap="http://usefulinc.com/ns/doap#"
#   xmlns:dc="http://purl.org/dc/elements/1.1/"
#   xmlns:ldp="http://www.w3.org/ns/ldp#"
#   xmlns:cert="http://www.w3.org/ns/auth/cert#"
#   xmlns:cc="http://creativecommons.org/ns#"
#   xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#   xmlns:default1="http://www.w3.org/ns/auth/acl#"
# >
#   <rdf:Description rdf:about="http://www.w3.org/People/Berners-Lee/card#i">
#     <owl:sameAs>
#       <con:Male rdf:about="https://www.w3.org/People/Berners-Lee/card#i">
#         <con:assistant rdf:resource="https://www.w3.org/People/Berners-Lee/card#amy"/>
#         <rdfs:label>Tim Berners-Lee</rdfs:label>
#         <vcard:hasAddress>
#           <vcard:Work rdf:nodeID="N537d8723354448bf866b4491c3e082d8">
#             <vcard:postal-code>02139</vcard:postal-code>
#             <vcard:locality>Cambridge</vcard:locality>
#             <vcard:region>MA</vcard:region>
#             <vcard:street-address>MIT room 32-G-52432 Vassar Street</vcard:street-address>
#           </vcard:Work>
#         </vcard:hasAddress>
#         <family_name>Berners-Lee</family_name>
#         <rdf:type rdf:resource="http://xmlns.com/foaf/0.1/Person"/>
#         <phone rdf:resource="tel:+1-(617)-253-5702"/>
#         <ldp:inbox rdf:resource="https://timbl.com/timbl/Public/Inbox"/>
#         <openid rdf:resource="https://www.w3.org/People/Berners-Lee/"/>
#         <img rdf:resource="https://www.w3.org/Press/Stock/Berners-Lee/2001-europaeum-eighth.jpg"/>
#         <sioc:avatar rdf:resource="http://www.w3.org/People/Berners-Lee/images/timbl-image-by-Coz-cropped.jpg"/>
#         <space:storage rdf:resource="https://timbl.databox.me/"/>
#         <vcard:fn>Tim Berners-Lee</vcard:fn>
#         <solid:oidcIssuer rdf:resource="https://timbl.com"/>
#         <homepage rdf:resource="https://www.w3.org/People/Berners-Lee/"/>
#         <nick>timbl</nick>
#         <account rdf:resource="http://www.reddit.com/user/timbl/"/>
#         <name>Timothy Berners-Lee</name>
#         <givenname>Timothy</givenname>
#         <con:office>
#           <rdf:Description rdf:nodeID="N61f759237b4c43a9ba01e7b4d753f8d2">
#             <con:phone rdf:resource="tel:+1-617-253-5702"/>
#             <con:address>
#               <rdf:Description rdf:nodeID="N736a3606ec4546b885c146c752e96ef4">
#                 <con:city>Cambridge</con:city>
#                 <con:street2>MIT CSAIL Room 32-G524</con:street2>
#                 <con:postalCode>02139</con:postalCode>
#                 <con:street>32 Vassar Street</con:street>
#                 <con:country>USA</con:country>
#               </rdf:Description>
#             </con:address>
#             <geo:location>
#               <rdf:Description rdf:nodeID="Nb0d7a01ccade44ccb0b832015f4d740e">
#                 <geo:lat>42.361860</geo:lat>
#                 <geo:long>-71.091840</geo:long>
#               </rdf:Description>
#             </geo:location>
#           </rdf:Description>
#         </con:office>
#         <weblog rdf:resource="http://dig.csail.mit.edu/breadcrumbs/blog/4"/>
#         <con:homePage rdf:resource="http://www.w3.org/People/Berners-Lee/"/>
#         <vcard:hasTelephone>
#           <vcard:Work rdf:nodeID="N626c7ff7bd9646ce87be64c25a47a0d2">
#             <vcard:value rdf:resource="tel:+1-617-253-5702"/>
#           </vcard:Work>
#         </vcard:hasTelephone>
#         <con:publicHomePage rdf:resource="http://www.w3.org/People/Berners-Lee/"/>
#         <default1:delegates rdf:resource="https://databox.me:3200/webid#me"/>
#         <nick>TimBL</nick>
#         <account rdf:resource="http://twitter.com/timberners_lee"/>
#         <mbox_sha1sum>965c47c5a70db7407210cef6e4e6f5374a525c5c</mbox_sha1sum>
#         <rdfs:seeAlso rdf:resource="https://timbl.com/timbl/Public/friends.ttl"/>
#         <workplaceHomepage rdf:resource="https://www.w3.org/"/>
#         <solid:publicTypeIndex rdf:resource="https://timbl.com/timbl/Public/PublicTypeIndex.ttl"/>
#         <con:preferredURI>https://www.w3.org/People/Berners-Lee/card#i</con:preferredURI>
#         <account rdf:resource="http://en.wikipedia.org/wiki/User:Timbl"/>
#         <based_near>
#           <rdf:Description rdf:nodeID="N8f4ab1e3535e421f89dc732ad8e84799">
#             <geo:lat>42.361860</geo:lat>
#             <geo:long>-71.091840</geo:long>
#           </rdf:Description>
#         </based_near>
#         <title>Sir</title>
#         <space:preferencesFile rdf:resource="https://timbl.com/timbl/Data/preferences.n3"/>
#         <mbox rdf:resource="mailto:timbl@w3.org"/>
#       </con:Male>
#     </owl:sameAs>
#     <cert:key>
#       <cert:RSAPublicKey rdf:nodeID="Nd83ca391bde94ea29bcc985d51834136">
#         <cert:exponent rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">65537</cert:exponent>
#         <cert:modulus rdf:datatype="http://www.w3.org/2001/XMLSchema#hexBinary">...</cert:modulus>
#       </cert:RSAPublicKey>
#     </cert:key>
#   </rdf:Description>
#   <rdf:Description rdf:about="http://www.w3.org/DesignIssues/Overview.html">
#     <maker rdf:resource="https://www.w3.org/People/Berners-Lee/card#i"/>
#     <dc:title>Design Issues for the World Wide Web</dc:title>
#   </rdf:Description>
#   <rdf:Description rdf:about="http://wiki.ontoworld.org/index.php/_IRW2006">
#     <dc:title>Identity, Reference and the Web workshop 2006</dc:title>
#     <con:participant rdf:resource="https://www.w3.org/People/Berners-Lee/card#i"/>
#   </rdf:Description>
#   <rdf:Description rdf:about="http://www.w3.org/2011/Talks/0331-hyderabad-tbl/data#talk">
#     <dct:title>Designing the Web for an Open Society</dct:title>
#     <maker rdf:resource="https://www.w3.org/People/Berners-Lee/card#i"/>
#   </rdf:Description>
#   <rdf:Description rdf:about="http://www.ecs.soton.ac.uk/~dt2/dlstuff/www2006_data#panel-panelk01">
#     <rdfs:label>The Next Wave of the Web (Plenary Panel)</rdfs:label>
#     <con:participant rdf:resource="https://www.w3.org/People/Berners-Lee/card#i"/>
#   </rdf:Description>
#   <PersonalProfileDocument rdf:about="http://www.w3.org/People/Berners-Lee/card">
#     <maker rdf:resource="https://www.w3.org/People/Berners-Lee/card#i"/>
#     <cc:license rdf:resource="http://creativecommons.org/licenses/by-nc/3.0/"/>
#     <dc:title>Tim Berners-Lee's FOAF file</dc:title>
#     <primaryTopic rdf:resource="https://www.w3.org/People/Berners-Lee/card#i"/>
#   </PersonalProfileDocument>
#   <rdf:Description rdf:about="http://www.w3.org/data#W3C">
#     <member rdf:resource="https://www.w3.org/People/Berners-Lee/card#i"/>
#   </rdf:Description>
#   <rdf:Description rdf:about="http://www.w3.org/2000/10/swap/data#Cwm">
#     <doap:developer rdf:resource="https://www.w3.org/People/Berners-Lee/card#i"/>
#   </rdf:Description>
#   <rdf:Description rdf:about="http://dig.csail.mit.edu/data#DIG">
#     <member rdf:resource="https://www.w3.org/People/Berners-Lee/card#i"/>
#   </rdf:Description>
#   <rdf:Description rdf:about="http://dig.csail.mit.edu/2007/01/camp/data#course">
#     <maker rdf:resource="https://www.w3.org/People/Berners-Lee/card#i"/>
#   </rdf:Description>
#   <rdf:Description rdf:about="http://dig.csail.mit.edu/2005/ajar/ajaw/data#Tabulator">
#     <doap:developer rdf:resource="https://www.w3.org/People/Berners-Lee/card#i"/>
#   </rdf:Description>
#   <PersonalProfileDocument rdf:about="https://timbl.com/timbl/Public/friends.ttl">
#     <primaryTopic rdf:resource="https://www.w3.org/People/Berners-Lee/card#i"/>
#     <dc:title>Tim Berners-Lee's editable FOAF file</dc:title>
#     <cc:license rdf:resource="http://creativecommons.org/licenses/by-nc/3.0/"/>
#     <maker rdf:resource="https://www.w3.org/People/Berners-Lee/card#i"/>
#   </PersonalProfileDocument>
#   <rdf:Description rdf:about="http://dig.csail.mit.edu/breadcrumbs/blog/4">
#     <rdfs:seeAlso rdf:resource="http://dig.csail.mit.edu/breadcrumbs/blog/feed/4"/>
#     <dc:title>timbl's blog on DIG</dc:title>
#     <maker rdf:resource="https://www.w3.org/People/Berners-Lee/card#i"/>
#   </rdf:Description>
# </rdf:RDF>

# %% [markdown]
# ### fetching another usual example: books from worldcat
#
# A common book

# %%
gcs = rdflib.Graph()
cs = gcs.parse("http://experiment.worldcat.org/oclc/751543198.rdf")
print("Graph has {} statements".format(len(gcs)))
# Out:
# Graph has 60 statements

# %% [markdown]
# #### Let's use this time a more human readable notation: _turtle_

# %%
print(gcs.serialize(format='turtle', encoding='utf-8').decode('utf-8'))
# Out:
# @prefix bgn: <http://bibliograph.net/> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix genont: <http://www.w3.org/2006/gen/ont#> .
# @prefix library: <http://purl.org/library/> .
# @prefix pto: <http://www.productontology.org/id/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix schema: <http://schema.org/> .
# @prefix umbel: <http://umbel.org/umbel#> .
# @prefix void: <http://rdfs.org/ns/void#> .
# @prefix wdrs: <http://www.w3.org/2007/05/powder-s#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://dewey.info/class/658.56/e22/> a schema:Intangible .
#
# <http://experiment.worldcat.org/entity/work/data/990314#Series/eco_efficiency_in_industry_and_science> a bgn:PublicationSeries ;
#     schema:hasPart <http://www.worldcat.org/oclc/751543198> ;
#     schema:name "Eco-efficiency in industry and science ;" .
#
# <http://id.loc.gov/authorities/subjects/sh2010108552> a schema:Intangible ;
#     schema:name "Product life cycle--Environmental aspects"@en .
#
# <http://id.loc.gov/vocabulary/countries/ne> a schema:Place ;
#     dcterms:identifier "ne" .
#
# <http://id.worldcat.org/fast/1078219> a schema:Intangible ;
#     schema:name "Product life cycle--Environmental aspects"@en .
#
# <http://viaf.org/viaf/1175433> a schema:Person ;
#     schema:familyName "Suh" ;
#     schema:givenName "Sangwon" ;
#     schema:name "Sangwon Suh" .
#
# <http://viaf.org/viaf/202382288> a schema:Person ;
#     schema:familyName "Heijungs" ;
#     schema:givenName "Reinout" ;
#     schema:name "Reinout Heijungs" .
#
# <http://worldcat.org/isbn/9789048160419> a schema:ProductModel ;
#     schema:isbn "9048160413",
#         "9789048160419" .
#
# <http://www.worldcat.org/title/-/oclc/751543198> a genont:ContentTypeGenericResource,
#         genont:InformationResource ;
#     void:inDataset <http://purl.oclc.org/dataset/WorldCat> ;
#     schema:about <http://www.worldcat.org/oclc/751543198> ;
#     schema:dateModified "2018-12-12" .
#
# <http://www.worldcat.org/title/-/oclc/751543198#PublicationEvent/dordrecht_london_springer_2011> a schema:PublicationEvent ;
#     schema:location <http://dbpedia.org/resource/London>,
#         <http://experiment.worldcat.org/entity/work/data/990314#Place/dordrecht> ;
#     schema:organizer <http://experiment.worldcat.org/entity/work/data/990314#Agent/springer> ;
#     schema:startDate "2011" .
#
# <http://dbpedia.org/resource/London> a schema:Place ;
#     schema:name "London" .
#
# <http://experiment.worldcat.org/entity/work/data/990314#Agent/springer> a bgn:Agent ;
#     schema:name "Springer" .
#
# <http://experiment.worldcat.org/entity/work/data/990314#Place/dordrecht> a schema:Place ;
#     schema:name "Dordrecht" .
#
# <http://www.worldcat.org/oclc/751543198> a schema:Book,
#         schema:CreativeWork ;
#     library:oclcnum "751543198" ;
#     library:placeOfPublication <http://dbpedia.org/resource/London>,
#         <http://experiment.worldcat.org/entity/work/data/990314#Place/dordrecht>,
#         <http://id.loc.gov/vocabulary/countries/ne> ;
#     schema:about <http://dewey.info/class/658.56/e22/>,
#         <http://id.loc.gov/authorities/subjects/sh2010108552>,
#         <http://id.worldcat.org/fast/1078219> ;
#     schema:bookFormat bgn:PrintBook ;
#     schema:contributor <http://viaf.org/viaf/1175433> ;
#     schema:creator <http://viaf.org/viaf/202382288> ;
#     schema:datePublished "2011" ;
#     schema:exampleOfWork <http://worldcat.org/entity/work/id/990314> ;
#     schema:inLanguage "en" ;
#     schema:isPartOf <http://experiment.worldcat.org/entity/work/data/990314#Series/eco_efficiency_in_industry_and_science> ;
#     schema:name "The computational structure of life cycle assessment"@en ;
#     schema:productID "751543198" ;
#     schema:publication <http://www.worldcat.org/title/-/oclc/751543198#PublicationEvent/dordrecht_london_springer_2011> ;
#     schema:publisher <http://experiment.worldcat.org/entity/work/data/990314#Agent/springer> ;
#     schema:workExample <http://worldcat.org/isbn/9789048160419> ;
#     umbel:isLike <http://bnb.data.bl.uk/id/resource/GBB125885> ;
#     wdrs:describedby <http://www.worldcat.org/title/-/oclc/751543198> .

# %% [markdown]
# #### Finaly, the json-ld notation, for ease of transport

# %%
import rdflib_jsonld
print(gcs.serialize(format='json-ld', encoding='utf-8').decode('utf-8'))
# Out:
# [
#   {
#     "@id": "http://www.worldcat.org/title/-/oclc/751543198",
#     "@type": [
#       "http://www.w3.org/2006/gen/ont#ContentTypeGenericResource",
#       "http://www.w3.org/2006/gen/ont#InformationResource"
#     ],
#     "http://rdfs.org/ns/void#inDataset": [
#       {
#         "@id": "http://purl.oclc.org/dataset/WorldCat"
#       }
#     ],
#     "http://schema.org/about": [
#       {
#         "@id": "http://www.worldcat.org/oclc/751543198"
#       }
#     ],
#     "http://schema.org/dateModified": [
#       {
#         "@value": "2018-12-12"
#       }
#     ]
#   },
#   {
#     "@id": "http://id.loc.gov/authorities/subjects/sh2010108552",
#     "@type": [
#       "http://schema.org/Intangible"
#     ],
#     "http://schema.org/name": [
#       {
#         "@language": "en",
#         "@value": "Product life cycle--Environmental aspects"
#       }
#     ]
#   },
#   {
#     "@id": "http://worldcat.org/isbn/9789048160419",
#     "@type": [
#       "http://schema.org/ProductModel"
#     ],
#     "http://schema.org/isbn": [
#       {
#         "@value": "9789048160419"
#       },
#       {
#         "@value": "9048160413"
#       }
#     ]
#   },
#   {
#     "@id": "http://id.loc.gov/vocabulary/countries/ne",
#     "@type": [
#       "http://schema.org/Place"
#     ],
#     "http://purl.org/dc/terms/identifier": [
#       {
#         "@value": "ne"
#       }
#     ]
#   },
#   {
#     "@id": "http://www.worldcat.org/oclc/751543198",
#     "@type": [
#       "http://schema.org/CreativeWork",
#       "http://schema.org/Book"
#     ],
#     "http://purl.org/library/oclcnum": [
#       {
#         "@value": "751543198"
#       }
#     ],
#     "http://purl.org/library/placeOfPublication": [
#       {
#         "@id": "http://id.loc.gov/vocabulary/countries/ne"
#       },
#       {
#         "@id": "http://experiment.worldcat.org/entity/work/data/990314#Place/dordrecht"
#       },
#       {
#         "@id": "http://dbpedia.org/resource/London"
#       }
#     ],
#     "http://schema.org/about": [
#       {
#         "@id": "http://dewey.info/class/658.56/e22/"
#       },
#       {
#         "@id": "http://id.worldcat.org/fast/1078219"
#       },
#       {
#         "@id": "http://id.loc.gov/authorities/subjects/sh2010108552"
#       }
#     ],
#     "http://schema.org/bookFormat": [
#       {
#         "@id": "http://bibliograph.net/PrintBook"
#       }
#     ],
#     "http://schema.org/contributor": [
#       {
#         "@id": "http://viaf.org/viaf/1175433"
#       }
#     ],
#     "http://schema.org/creator": [
#       {
#         "@id": "http://viaf.org/viaf/202382288"
#       }
#     ],
#     "http://schema.org/datePublished": [
#       {
#         "@value": "2011"
#       }
#     ],
#     "http://schema.org/exampleOfWork": [
#       {
#         "@id": "http://worldcat.org/entity/work/id/990314"
#       }
#     ],
#     "http://schema.org/inLanguage": [
#       {
#         "@value": "en"
#       }
#     ],
#     "http://schema.org/isPartOf": [
#       {
#         "@id": "http://experiment.worldcat.org/entity/work/data/990314#Series/eco_efficiency_in_industry_and_science"
#       }
#     ],
#     "http://schema.org/name": [
#       {
#         "@language": "en",
#         "@value": "The computational structure of life cycle assessment"
#       }
#     ],
#     "http://schema.org/productID": [
#       {
#         "@value": "751543198"
#       }
#     ],
#     "http://schema.org/publication": [
#       {
#         "@id": "http://www.worldcat.org/title/-/oclc/751543198#PublicationEvent/dordrecht_london_springer_2011"
#       }
#     ],
#     "http://schema.org/publisher": [
#       {
#         "@id": "http://experiment.worldcat.org/entity/work/data/990314#Agent/springer"
#       }
#     ],
#     "http://schema.org/workExample": [
#       {
#         "@id": "http://worldcat.org/isbn/9789048160419"
#       }
#     ],
#     "http://umbel.org/umbel#isLike": [
#       {
#         "@id": "http://bnb.data.bl.uk/id/resource/GBB125885"
#       }
#     ],
#     "http://www.w3.org/2007/05/powder-s#describedby": [
#       {
#         "@id": "http://www.worldcat.org/title/-/oclc/751543198"
#       }
#     ]
#   },
#   {
#     "@id": "http://experiment.worldcat.org/entity/work/data/990314#Place/dordrecht",
#     "@type": [
#       "http://schema.org/Place"
#     ],
#     "http://schema.org/name": [
#       {
#         "@value": "Dordrecht"
#       }
#     ]
#   },
#   {
#     "@id": "http://experiment.worldcat.org/entity/work/data/990314#Agent/springer",
#     "@type": [
#       "http://bibliograph.net/Agent"
#     ],
#     "http://schema.org/name": [
#       {
#         "@value": "Springer"
#       }
#     ]
#   },
#   {
#     "@id": "http://experiment.worldcat.org/entity/work/data/990314#Series/eco_efficiency_in_industry_and_science",
#     "@type": [
#       "http://bibliograph.net/PublicationSeries"
#     ],
#     "http://schema.org/hasPart": [
#       {
#         "@id": "http://www.worldcat.org/oclc/751543198"
#       }
#     ],
#     "http://schema.org/name": [
#       {
#         "@value": "Eco-efficiency in industry and science ;"
#       }
#     ]
#   },
#   {
#     "@id": "http://www.worldcat.org/title/-/oclc/751543198#PublicationEvent/dordrecht_london_springer_2011",
#     "@type": [
#       "http://schema.org/PublicationEvent"
#     ],
#     "http://schema.org/location": [
#       {
#         "@id": "http://experiment.worldcat.org/entity/work/data/990314#Place/dordrecht"
#       },
#       {
#         "@id": "http://dbpedia.org/resource/London"
#       }
#     ],
#     "http://schema.org/organizer": [
#       {
#         "@id": "http://experiment.worldcat.org/entity/work/data/990314#Agent/springer"
#       }
#     ],
#     "http://schema.org/startDate": [
#       {
#         "@value": "2011"
#       }
#     ]
#   },
#   {
#     "@id": "http://dbpedia.org/resource/London",
#     "@type": [
#       "http://schema.org/Place"
#     ],
#     "http://schema.org/name": [
#       {
#         "@value": "London"
#       }
#     ]
#   },
#   {
#     "@id": "http://id.worldcat.org/fast/1078219",
#     "@type": [
#       "http://schema.org/Intangible"
#     ],
#     "http://schema.org/name": [
#       {
#         "@language": "en",
#         "@value": "Product life cycle--Environmental aspects"
#       }
#     ]
#   },
#   {
#     "@id": "http://viaf.org/viaf/1175433",
#     "@type": [
#       "http://schema.org/Person"
#     ],
#     "http://schema.org/familyName": [
#       {
#         "@value": "Suh"
#       }
#     ],
#     "http://schema.org/givenName": [
#       {
#         "@value": "Sangwon"
#       }
#     ],
#     "http://schema.org/name": [
#       {
#         "@value": "Sangwon Suh"
#       }
#     ]
#   },
#   {
#     "@id": "http://dewey.info/class/658.56/e22/",
#     "@type": [
#       "http://schema.org/Intangible"
#     ]
#   },
#   {
#     "@id": "http://viaf.org/viaf/202382288",
#     "@type": [
#       "http://schema.org/Person"
#     ],
#     "http://schema.org/familyName": [
#       {
#         "@value": "Heijungs"
#       }
#     ],
#     "http://schema.org/givenName": [
#       {
#         "@value": "Reinout"
#       }
#     ],
#     "http://schema.org/name": [
#       {
#         "@value": "Reinout Heijungs"
#       }
#     ]
#   }
# ]
